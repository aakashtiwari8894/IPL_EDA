# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\User\\Desktop\\ML PROJECTS\\IPL_DATA\\matches.csv")  # loading dataset

# %%
df.head()                       #top 5 records
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.shape                                                       # looking number of rows and column in data set
# Out:
# (756, 18)

# %%
df.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df["player_of_match"].value_counts()                           # frequency of man of match awards
# Out:
# CH Gayle             21
# AB de Villiers       20
# RG Sharma            17
# MS Dhoni             17
# DA Warner            17
#                      ..
# CR Brathwaite         1
# Kuldeep Yadav         1
# A Joseph              1
# Mustafizur Rahman     1
# S Anirudha            1
# Name: player_of_match, Length: 226, dtype: int64

# %%
df["player_of_match"].value_counts().head(10)                   #top ten palyer with most man of the match award
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# Name: player_of_match, dtype: int64

# %%
df["player_of_match"].value_counts()[0:5]                          #top five palyer with most man of the match award
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# Name: player_of_match, dtype: int64

# %%
list(df["player_of_match"].value_counts()[0:5].keys())            # names of player
# Out:
# ['CH Gayle', 'AB de Villiers', 'RG Sharma', 'MS Dhoni', 'DA Warner']

# %%
list(df["player_of_match"].value_counts()[0:5])                    # score of player
# Out:
# [21, 20, 17, 17, 17]

# %%
plt.figure(figsize=(9,6))
plt.title("Player with highest Man of Match frequency ")
plt.bar(list(df["player_of_match"].value_counts()[0:5].keys()), list(df["player_of_match"].value_counts()[0:5]),color="red")
plt.xlabel("PLAYERS")
plt.ylabel("FREQUENCY")
plt.show()

# %%
df["result"].value_counts()                     #condition of match
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
df["toss_winner"].value_counts()                 #frequency
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Kings XI Punjab                81
# Royal Challengers Bangalore    81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
batting_first=df[df["win_by_runs"]!=0]    # team bat first won match

# %%
batting_first
# Out:
#         id    Season       city        date                        team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13      14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# ..     ...       ...        ...         ...                          ...
# 741  11337  IPL-2019      Delhi  28-04-2019               Delhi Capitals
# 742  11338  IPL-2019    Kolkata  28-04-2019        Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019          Sunrisers Hyderabad
# 745  11341  IPL-2019    Chennai  01-05-2019          Chennai Super Kings
# 755  11415  IPL-2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
batting_first.head()
# Out:
#     id    Season       city        date                        team1  \
# 0    1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4    5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13  14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14  15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
plt.figure(figsize=(7,5))
plt.hist(batting_first["win_by_runs"])
plt.title("Distrubution of win by run")
plt.xlabel("Runs")
plt.show()

# %%
batting_first["winner"].value_counts()      #team with most win batting first
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
list(batting_first["winner"].value_counts())
# Out:
# [57, 52, 38, 36, 35, 30, 27, 25, 18, 6, 5, 3, 2, 2, 1]

# %%
plt.figure(figsize=(12,7))
plt.bar(list(batting_first["winner"].value_counts()[0:5].keys()),list(batting_first["winner"].value_counts()[0:5]),color=["g","r","b","m","y"])
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.pie(list(batting_first["winner"].value_counts()),labels=list(batting_first["winner"].value_counts().keys()),autopct="%0.1f%%")
plt.show()

# %%
batting_second=df[df["win_by_wickets"]!=0]             # team win after batting second

# %%
batting_second
# Out:
#         id    Season           city        date                   team1  \
# 1        2  IPL-2017           Pune  06-04-2017          Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017           Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017  Rising Pune Supergiant
# 5        6  IPL-2017      Hyderabad  09-04-2017           Gujarat Lions
# 6        7  IPL-2017         Mumbai  09-04-2017   Kolkata Knight Riders
# ..     ...       ...            ...         ...                     ...
# 750  11346  IPL-2019         Mohali  05-05-2019     Chennai Super Kings
# 751  11347  IPL-2019         Mumbai  05-05-2019   Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019     Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019     Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
batting_second["winner"].value_counts()          # team with number of win on batting second
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Chennai Super Kings            48
# Royal Challengers Bangalore    48
# Rajasthan Royals               46
# Delhi Daredevils               42
# Kings XI Punjab                42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Delhi Capitals                  6
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title("Top run chase team")
plt.bar(list(batting_second["winner"].value_counts()[0:4].keys()),list(batting_second["winner"].value_counts()[0:4]),color=['r','g','b','y','m'])
plt.xlabel("Teams")
plt.ylabel("win matches")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.hist(batting_second["win_by_wickets"],bins=30)
plt.xlabel("Number of wickets")
plt.ylabel("Number of matches")
plt.show()

# %%
df["Season"].value_counts()          #number of matches in one season
# Out:
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2018    60
# IPL-2016    60
# IPL-2010    60
# IPL-2014    60
# IPL-2019    60
# IPL-2017    59
# IPL-2015    59
# IPL-2008    58
# IPL-2009    57
# Name: Season, dtype: int64

# %%
df["city"].value_counts()          # number of matches in each city
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Mohali             10
# Rajkot             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cape Town           7
# Port Elizabeth      7
# Ranchi              7
# Cuttack             7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Nagpur              3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
df_2=df[df["toss_winner"] == df["winner"]]       # sub-data set for winning team after winning toss

# %%
df_2
# Out:
#         id    Season           city        date                        team1  \
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 5        6  IPL-2017      Hyderabad  09-04-2017                Gujarat Lions
# ..     ...       ...            ...         ...                          ...
# 750  11346  IPL-2019         Mohali  05-05-2019          Chennai Super Kings
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
np.sum(df["toss_winner"] == df["winner"])       #number of matches where team win on batting second
# Out:
# 393

# %%
df_2["winner"].value_counts()         # team withnumber of  win after winning toss
# Out:
# Chennai Super Kings            57
# Mumbai Indians                 56
# Kolkata Knight Riders          53
# Rajasthan Royals               42
# Royal Challengers Bangalore    41
# Delhi Daredevils               35
# Kings XI Punjab                35
# Sunrisers Hyderabad            23
# Deccan Chargers                19
# Gujarat Lions                  10
# Delhi Capitals                  7
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Pune Warriors                   3
# Name: winner, dtype: int64

# %%
df["winner"].value_counts()     # number of win in entire data set
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64
